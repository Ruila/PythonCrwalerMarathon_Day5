# %% [markdown]
# # API 資料串接 - 以 Dcard API 實作範例
#
# * 了解 Dcard API 使用方式與回傳內容
# * 撰寫程式存取 API 且解析 JSON 格式資料

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

# %%
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？

#Ans:  30筆資料，每筆資料有37-38個欄位（欄位如print）

import requests
import json
r = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')
response = r.text
json.loads(r.text)

# print(json.loads(response))
# Out:
# [{'id': 235042578,
#   'title': '狗媽媽活凍成冰雕，還緊護7隻寶寶',
#   'excerpt': '12月已進入寒冬，在俄羅斯的克拉斯諾雅斯克（Krasnoyarsk）天氣更來到零下20度！有居民發現，有隻狗媽媽抱著七隻小狗，躺在雪地上。走近一看，才發現這隻狗媽媽因天氣過於寒冷，已活活被凍死。看這姿',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-12-24T09:21:46.019Z',
#   'updatedAt': '2020-12-24T09:21:46.019Z',
#   'commentCount': 21,
#   'likeCount': 2916,
#   'withNickname': False,
#   'tags': [],
#   'topics': [],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '國立臺灣大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': 'bd8c51e0-3c8b-48d3-915c-5a61f6716cc3',
#     'url': 'https://i.imgur.com/go4sUn6l.jpg',
#     'normalizedUrl': 'https://i.imgur.com/go4sUn6l.jpg',
#     'thumbnail': 'https://i.imgur.com/go4sUn6l.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T09:21:46.019Z',
#     'updatedAt': '2020-12-24T09:21:46.019Z',
#     'width': 640,
#     'height': 360},
#    {'id': 'bd8c51e0-3c8b-48d3-915c-5a61f6716cc3',
#     'url': 'https://i.imgur.com/go4sUn6.jpg',
#     'normalizedUrl': 'https://imgur.com/go4sUn6',
#     'thumbnail': 'https://i.imgur.com/go4sUn6l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T09:21:46.019Z',
#     'updatedAt': '2020-12-24T09:21:46.019Z',
#     'width': 640,
#     'height': 360},
#    {'id': '3f484012-fa17-445f-9570-fd583101cbb6',
#     'url': 'https://i.imgur.com/PwfNDZH.jpg',
#     'normalizedUrl': 'https://imgur.com/PwfNDZH',
#     'thumbnail': 'https://i.imgur.com/PwfNDZHl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T09:21:46.019Z',
#     'updatedAt': '2020-12-24T09:21:46.019Z',
#     'width': 846,
#     'height': 570},
#    {'id': 'e79167c8-0f59-402f-9c7b-f1290fbe163b',
#     'url': 'https://i.imgur.com/ujMzxC0.jpg',
#     'normalizedUrl': 'https://imgur.com/ujMzxC0',
#     'thumbnail': 'https://i.imgur.com/ujMzxC0l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T09:21:46.019Z',
#     'updatedAt': '2020-12-24T09:21:46.019Z',
#     'width': 801,
#     'height': 572}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 2497},
#    {'id': '514c2569-fd53-4d9d-a415-bf0f88e7329f', 'count': 396},
#    {'id': '011ead16-9b83-4729-9fde-c588920c6c2d', 'count': 19},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 2},
#    {'id': '4b018f48-e184-445f-adf1-fc8e04ba09b9', 'count': 1},
#    {'id': 'aa0d425f-d530-4478-9a77-fe3aedc79eea', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/go4sUn6.jpg'},
#    {'url': 'https://i.imgur.com/PwfNDZH.jpg'},
#    {'url': 'https://i.imgur.com/ujMzxC0.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 235044312,
#   'title': '喜歡的寵物店狗狗被買走了',
#   'excerpt': '原本左下角是住一隻米格魯幼犬，我每次經過都會特地看牠好幾眼，牠都一直在籠子裡面轉圈圈，好像精力永不耗盡，然而我今天早上經過的時候，發現原本牠住著的那一格空了，只能希望牠是去到了一戶好人家，拜託拜託了',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-12-24T14:20:04.070Z',
#   'updatedAt': '2020-12-24T14:20:04.070Z',
#   'commentCount': 32,
#   'likeCount': 793,
#   'withNickname': False,
#   'tags': [],
#   'topics': [],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '國立政治大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': 'db27571d-b4eb-4b1f-956f-9056a43cd01f',
#     'url': 'https://i.imgur.com/olvZ740l.jpg',
#     'normalizedUrl': 'https://i.imgur.com/olvZ740l.jpg',
#     'thumbnail': 'https://i.imgur.com/olvZ740l.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T14:20:04.070Z',
#     'updatedAt': '2020-12-24T14:20:04.070Z',
#     'width': 2000,
#     'height': 1500},
#    {'id': 'db27571d-b4eb-4b1f-956f-9056a43cd01f',
#     'url': 'https://i.imgur.com/olvZ740.jpg',
#     'normalizedUrl': 'https://imgur.com/olvZ740',
#     'thumbnail': 'https://i.imgur.com/olvZ740l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T14:20:04.070Z',
#     'updatedAt': '2020-12-24T14:20:04.070Z',
#     'width': 2000,
#     'height': 1500}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 773},
#    {'id': '514c2569-fd53-4d9d-a415-bf0f88e7329f', 'count': 16},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 2},
#    {'id': '4b018f48-e184-445f-adf1-fc8e04ba09b9', 'count': 1},
#    {'id': 'aa0d425f-d530-4478-9a77-fe3aedc79eea', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/olvZ740.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 235042882,
#   'title': '求助！貓貓發霉了😫',
#   'excerpt': '打給賀！我是肉包媽（第一次發文請見諒），肉包目前兩個月又9天大，上個禮拜發現牠耳朵黑黑的，上網查後發現疑似黴菌就馬上帶去動物醫院檢查，醫生說還太小沒辦法吃藥，但也沒有開藥（擦的、藥浴）給我，只叫我用吹',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-12-24T10:22:32.116Z',
#   'updatedAt': '2020-12-24T10:24:08.443Z',
#   'commentCount': 34,
#   'likeCount': 273,
#   'withNickname': True,
#   'tags': ['HIDE_THUMBNAIL'],
#   'topics': ['寵物', '貓', '可愛'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '罵包の媽咪',
#   'department': 'yuu_ruu',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '6e9c52de-9787-484c-b29f-9e7c31dd71ee',
#     'url': 'https://i.imgur.com/ojd9Jmu.jpg',
#     'normalizedUrl': 'https://imgur.com/ojd9Jmu',
#     'thumbnail': 'https://i.imgur.com/ojd9Jmul.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T10:22:32.116Z',
#     'updatedAt': '2020-12-24T10:24:08.443Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '9ccb2baf-bc7a-41ad-a6c6-ccb934a96f99',
#     'url': 'https://i.imgur.com/GCzGryy.jpg',
#     'normalizedUrl': 'https://imgur.com/GCzGryy',
#     'thumbnail': 'https://i.imgur.com/GCzGryyl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T10:22:32.116Z',
#     'updatedAt': '2020-12-24T10:24:08.443Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': 'd405cb4f-ff7b-481f-ab4a-536efde85140',
#     'url': 'https://i.imgur.com/Tko5zDg.jpg',
#     'normalizedUrl': 'https://imgur.com/Tko5zDg',
#     'thumbnail': 'https://i.imgur.com/Tko5zDgl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T10:22:32.116Z',
#     'updatedAt': '2020-12-24T10:24:08.443Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': 'a996d821-7d4f-4f51-9949-442f0b1af070',
#     'url': 'https://i.imgur.com/7FvAjFd.jpg',
#     'normalizedUrl': 'https://imgur.com/7FvAjFd',
#     'thumbnail': 'https://i.imgur.com/7FvAjFdl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T10:22:32.116Z',
#     'updatedAt': '2020-12-24T10:24:08.443Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '0a65c39b-fa9c-4b21-9ee1-c893ced56f78',
#     'url': 'https://i.imgur.com/SJbTx5d.jpg',
#     'normalizedUrl': 'https://imgur.com/SJbTx5d',
#     'thumbnail': 'https://i.imgur.com/SJbTx5dl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T10:22:32.116Z',
#     'updatedAt': '2020-12-24T10:24:08.443Z',
#     'width': 2000,
#     'height': 1500},
#    {'id': '6ce06487-a0f2-4627-9eed-24e5efb4f73b',
#     'url': 'https://i.imgur.com/Db81JKw.jpg',
#     'normalizedUrl': 'https://imgur.com/Db81JKw',
#     'thumbnail': 'https://i.imgur.com/Db81JKwl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T10:22:32.116Z',
#     'updatedAt': '2020-12-24T10:24:08.443Z',
#     'width': 2000,
#     'height': 1500}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 272},
#    {'id': 'aa0d425f-d530-4478-9a77-fe3aedc79eea', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'withImages': True,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 235041610,
#   'title': '貓咪很秀氣的嘎嘎聲',
#   'excerpt': '貓咪喜歡看小鳥，而主人我也最愛觀察她看小鳥了（˶‾᷄ ⁻̫ ‾᷅˵），之前以為她看到小鳥不會有嘎嘎的聲音，大部分都是像這樣認真欣賞小鳥（？結果後來發現原來她也會嘎嘎叫，只是很秀氣非常無害🤣，最喜歡在窗戶邊看',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-12-24T06:19:34.462Z',
#   'updatedAt': '2020-12-24T06:19:34.462Z',
#   'commentCount': 15,
#   'likeCount': 218,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['寵物', '貓', '可愛', '捲耳貓'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '黑豆雪球喵',
#   'department': 'kuromame',
#   'replyTitle': None,
#   'mediaMeta': [{'id': 'dca96461-168b-4cca-a60c-2d217bb8fc97',
#     'url': 'https://vivid.dcard.tw/Public/34c13fa1-4080-4e79-ab07-1861e4af8b64/thumbnail.jpg',
#     'normalizedUrl': 'https://vivid.dcard.tw/Public/34c13fa1-4080-4e79-ab07-1861e4af8b64/thumbnail.jpg',
#     'thumbnail': 'https://vivid.dcard.tw/Public/34c13fa1-4080-4e79-ab07-1861e4af8b64/thumbnail.jpg',
#     'type': 'image/thumbnail',
#     'tags': [],
#     'createdAt': '2020-12-24T06:19:34.462Z',
#     'updatedAt': '2020-12-24T06:19:34.462Z'},
#    {'id': 'dca96461-168b-4cca-a60c-2d217bb8fc97',
#     'url': 'https://www.dcard.tw/v2/vivid/videos/34c13fa1-4080-4e79-ab07-1861e4af8b64?r=1.7777777777777777',
#     'normalizedUrl': '',
#     'thumbnail': 'https://vivid.dcard.tw/Public/34c13fa1-4080-4e79-ab07-1861e4af8b64/thumbnail.jpg',
#     'type': 'video/vivid',
#     'tags': [],
#     'createdAt': '2020-12-24T06:19:34.462Z',
#     'updatedAt': '2020-12-24T06:19:34.462Z'},
#    {'id': 'a38fbb65-47b5-42e9-a3c1-bb9e914a1dd5',
#     'url': 'https://www.dcard.tw/v2/vivid/videos/6f92c964-6835-4e73-bdcf-119a2f9f3acc?r=1.7777777777777777',
#     'normalizedUrl': '',
#     'thumbnail': 'https://vivid.dcard.tw/Public/6f92c964-6835-4e73-bdcf-119a2f9f3acc/thumbnail.jpg',
#     'type': 'video/vivid',
#     'tags': [],
#     'createdAt': '2020-12-24T06:19:34.462Z',
#     'updatedAt': '2020-12-24T06:19:34.462Z'},
#    {'id': 'e6568d6c-db2b-4aeb-a994-12849ee55365',
#     'url': 'https://i.imgur.com/qVOTaj1.jpg',
#     'normalizedUrl': 'https://imgur.com/qVOTaj1',
#     'thumbnail': 'https://i.imgur.com/qVOTaj1l.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-24T06:19:34.462Z',
#     'updatedAt': '2020-12-24T06:19:34.462Z',
#     'width': 1500,
#     'height': 2000}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 217},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'withImages': True,
#   'withVideos': True,
#   'media': [{'url': 'https://vivid.dcard.tw/Public/34c13fa1-4080-4e79-ab07-1861e4af8b64/thumbnail.jpg'},
#    {'url': 'https://vivid.dcard.tw/Public/6f92c964-6835-4e73-bdcf-119a2f9f3acc/thumbnail.jpg'},
#    {'url': 'https://i.imgur.com/qVOTaj1.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 235041867,
#   'title': '是會不會吃飯啦😂',
#   'excerpt': '一群小笨蛋（*´∀`）~',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-12-24T07:07:50.904Z',
#   'updatedAt': '2020-12-24T07:07:50.904Z',
#   'commentCount': 8,
#   'likeCount': 205,
#   'withNickname': True,
#   'tags': [],
#   'topics': [],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '蓉の貓',
#   'department': 'dickdicklong',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '8fd70256-2ba4-41a1-8cfd-2cd851e8b169',
#     'url': 'https://i.imgur.com/uhVnDZJl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/uhVnDZJl.jpg',
#     'thumbnail': 'https://i.imgur.com/uhVnDZJl.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T07:07:50.904Z',
#     'updatedAt': '2020-12-24T07:07:50.904Z',
#     'width': 627,
#     'height': 671},
#    {'id': '8fd70256-2ba4-41a1-8cfd-2cd851e8b169',
#     'url': 'https://i.imgur.com/uhVnDZJ.png',
#     'normalizedUrl': 'https://imgur.com/uhVnDZJ',
#     'thumbnail': 'https://i.imgur.com/uhVnDZJl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T07:07:50.904Z',
#     'updatedAt': '2020-12-24T07:07:50.904Z',
#     'width': 627,
#     'height': 671},
#    {'id': 'f63ceeee-3d85-4ec8-81e6-1c20f1219c2a',
#     'url': 'https://i.imgur.com/swfX8nO.png',
#     'normalizedUrl': 'https://imgur.com/swfX8nO',
#     'thumbnail': 'https://i.imgur.com/swfX8nOl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T07:07:50.904Z',
#     'updatedAt': '2020-12-24T07:07:50.904Z',
#     'width': 514,
#     'height': 752},
#    {'id': '02170f4c-00c6-45fe-b5d3-f50176c274b3',
#     'url': 'https://i.imgur.com/YYMdggm.png',
#     'normalizedUrl': 'https://imgur.com/YYMdggm',
#     'thumbnail': 'https://i.imgur.com/YYMdggml.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T07:07:50.904Z',
#     'updatedAt': '2020-12-24T07:07:50.904Z',
#     'width': 720,
#     'height': 708},
#    {'id': 'dd8dbc4d-bec8-4d0e-b97b-09d279af880d',
#     'url': 'https://i.imgur.com/hwKc6p8.jpg',
#     'normalizedUrl': 'https://imgur.com/hwKc6p8',
#     'thumbnail': 'https://i.imgur.com/hwKc6p8l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T07:07:50.904Z',
#     'updatedAt': '2020-12-24T07:07:50.904Z',
#     'width': 720,
#     'height': 960},
#    {'id': '094bb78e-70d0-48fd-b7d9-65def25b5863',
#     'url': 'https://i.imgur.com/fKgbLnG.png',
#     'normalizedUrl': 'https://imgur.com/fKgbLnG',
#     'thumbnail': 'https://i.imgur.com/fKgbLnGl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T07:07:50.904Z',
#     'updatedAt': '2020-12-24T07:07:50.904Z',
#     'width': 547,
#     'height': 554},
#    {'id': '5f5fe302-89ac-4153-a01a-073b7a5e3ea9',
#     'url': 'https://i.imgur.com/nB1gqsT.png',
#     'normalizedUrl': 'https://imgur.com/nB1gqsT',
#     'thumbnail': 'https://i.imgur.com/nB1gqsTl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T07:07:50.904Z',
#     'updatedAt': '2020-12-24T07:07:50.904Z',
#     'width': 712,
#     'height': 534}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 191},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 14}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/uhVnDZJ.png'},
#    {'url': 'https://i.imgur.com/swfX8nO.png'},
#    {'url': 'https://i.imgur.com/YYMdggm.png'},
#    {'url': 'https://i.imgur.com/hwKc6p8.jpg'},
#    {'url': 'https://i.imgur.com/fKgbLnG.png'},
#    {'url': 'https://i.imgur.com/nB1gqsT.png'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 235040083,
#   'title': '被留在公車上的狗狗(611公車上)',
#   'excerpt': '今天早上8：30的時候發現 有人把牠留在公車上，希望牠的主人看到這篇文章可以趕快去找它🥺🥺，我已經跟公車司機說囉！',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-12-24T01:23:13.256Z',
#   'updatedAt': '2020-12-25T03:47:14.549Z',
#   'commentCount': 21,
#   'likeCount': 200,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['狗狗', '貴賓狗', '公車', '走失'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '中國科技大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '23a71577-5a78-49b7-94fa-43280afdc956',
#     'url': 'https://i.imgur.com/jrnKf9ul.jpg',
#     'normalizedUrl': 'https://i.imgur.com/jrnKf9ul.jpg',
#     'thumbnail': 'https://i.imgur.com/jrnKf9ul.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T07:55:12.670Z',
#     'updatedAt': '2020-12-25T03:47:14.549Z',
#     'width': 1918,
#     'height': 2000},
#    {'id': '23a71577-5a78-49b7-94fa-43280afdc956',
#     'url': 'https://i.imgur.com/jrnKf9u.jpg',
#     'normalizedUrl': 'https://imgur.com/jrnKf9u',
#     'thumbnail': 'https://i.imgur.com/jrnKf9ul.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T07:55:12.670Z',
#     'updatedAt': '2020-12-25T03:47:14.549Z',
#     'width': 1918,
#     'height': 2000}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 184},
#    {'id': '514c2569-fd53-4d9d-a415-bf0f88e7329f', 'count': 6},
#    {'id': '4b018f48-e184-445f-adf1-fc8e04ba09b9', 'count': 5},
#    {'id': 'aa0d425f-d530-4478-9a77-fe3aedc79eea', 'count': 4},
#    {'id': '011ead16-9b83-4729-9fde-c588920c6c2d', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/jrnKf9u.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 235042108,
#   'title': '是一糰棉花糖！',
#   'excerpt': '雖然叫逼波，但是是一枚小男生 沒錯⋯⋯，首圖先來張應景的祝大家聖誕節快樂！，好久沒剃毛了，最近就長成了一坨會呼吸的棉花糖🤣，上次還撿到了一根他的鬍鬚！！，聽說撿到貓咪的鬍鬚會帶來好運⋯⋯嗎（？），最喜',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-12-24T07:52:22.425Z',
#   'updatedAt': '2020-12-24T08:16:35.334Z',
#   'commentCount': 10,
#   'likeCount': 167,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['貓', '可愛'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '長庚科技大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '9ecf6f5c-42dd-45b5-8f86-225aa0fa914a',
#     'url': 'https://i.imgur.com/kXfupqYl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/kXfupqYl.jpg',
#     'thumbnail': 'https://i.imgur.com/kXfupqYl.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T07:52:22.425Z',
#     'updatedAt': '2020-12-24T08:16:35.334Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '9ecf6f5c-42dd-45b5-8f86-225aa0fa914a',
#     'url': 'https://i.imgur.com/kXfupqY.jpg',
#     'normalizedUrl': 'https://imgur.com/kXfupqY',
#     'thumbnail': 'https://i.imgur.com/kXfupqYl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T07:52:22.425Z',
#     'updatedAt': '2020-12-24T08:16:35.334Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '011d0de9-82fb-4ac6-8cf8-1b40c931fbe4',
#     'url': 'https://i.imgur.com/SecA3Hb.jpg',
#     'normalizedUrl': 'https://imgur.com/SecA3Hb',
#     'thumbnail': 'https://i.imgur.com/SecA3Hbl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T07:52:22.425Z',
#     'updatedAt': '2020-12-24T08:16:35.334Z',
#     'width': 1108,
#     'height': 1478},
#    {'id': '495bd62e-b423-4f77-b40f-775ce84e8668',
#     'url': 'https://i.imgur.com/weLL3ME.jpg',
#     'normalizedUrl': 'https://imgur.com/weLL3ME',
#     'thumbnail': 'https://i.imgur.com/weLL3MEl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T07:52:22.425Z',
#     'updatedAt': '2020-12-24T08:16:35.334Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': '84975186-3c5c-4fee-912a-88c865b7d0c8',
#     'url': 'https://i.imgur.com/jnbMzMN.jpg',
#     'normalizedUrl': 'https://imgur.com/jnbMzMN',
#     'thumbnail': 'https://i.imgur.com/jnbMzMNl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T07:52:22.425Z',
#     'updatedAt': '2020-12-24T08:16:35.334Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '9931c66d-b0ce-4abf-bc8d-683e979fe06b',
#     'url': 'https://www.dcard.tw/v2/vivid/videos/b3508448-af98-4668-a75d-e8fe33383b08?r=1.7777777777777777',
#     'normalizedUrl': '',
#     'thumbnail': 'https://vivid.dcard.tw/Public/b3508448-af98-4668-a75d-e8fe33383b08/thumbnail.jpg',
#     'type': 'video/vivid',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2020-12-24T08:16:35.334Z',
#     'updatedAt': '2020-12-24T08:16:35.334Z'},
#    {'id': '49dcb51e-0b21-4d4d-9e1c-10139630e57b',
#     'url': 'https://i.imgur.com/xyJITJV.jpg',
#     'normalizedUrl': 'https://imgur.com/xyJITJV',
#     'thumbnail': 'https://i.imgur.com/xyJITJVl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T07:52:22.425Z',
#     'updatedAt': '2020-12-24T08:16:35.334Z',
#     'width': 1500,
#     'height': 2000}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 164},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 2},
#    {'id': '011ead16-9b83-4729-9fde-c588920c6c2d', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'withImages': True,
#   'withVideos': True,
#   'media': [{'url': 'https://i.imgur.com/kXfupqY.jpg'},
#    {'url': 'https://i.imgur.com/SecA3Hb.jpg'},
#    {'url': 'https://i.imgur.com/weLL3ME.jpg'},
#    {'url': 'https://i.imgur.com/jnbMzMN.jpg'},
#    {'url': 'https://vivid.dcard.tw/Public/b3508448-af98-4668-a75d-e8fe33383b08/thumbnail.jpg'},
#    {'url': 'https://i.imgur.com/xyJITJV.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 235046334,
#   'title': '我與膽小貓的故事',
#   'excerpt': '嗨 這是果果剛誘捕回家還在陽台隔離的時候（大約是去年十二月），故事的一開始 要從 我發現我家附近有小浪貓，因為冬天很冷，我想說要去找愛媽之類的來誘捕請她們送養，我找到了某送養貓新聞上的愛媽私訊她（雖然',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-12-24T21:02:05.857Z',
#   'updatedAt': '2020-12-24T21:07:28.019Z',
#   'commentCount': 10,
#   'likeCount': 148,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['貓', '寵物', '米克斯', '親人訓練'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '耕莘健康管理專科學校',
#   'department': '護理科',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '5487e175-73a4-4b41-8962-16878ac58cc7',
#     'url': 'https://i.imgur.com/rMF6wO7l.jpg',
#     'normalizedUrl': 'https://i.imgur.com/rMF6wO7l.jpg',
#     'thumbnail': 'https://i.imgur.com/rMF6wO7l.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T21:02:05.857Z',
#     'updatedAt': '2020-12-24T21:07:28.019Z',
#     'width': 960,
#     'height': 1706,
#     'croppingWindow': {'anchorX': 0,
#      'anchorY': 0,
#      'width': 960,
#      'height': 1280}},
#    {'id': '5487e175-73a4-4b41-8962-16878ac58cc7',
#     'url': 'https://i.imgur.com/rMF6wO7.jpg',
#     'normalizedUrl': 'https://imgur.com/rMF6wO7',
#     'thumbnail': 'https://i.imgur.com/rMF6wO7l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T21:02:05.857Z',
#     'updatedAt': '2020-12-24T21:07:28.019Z',
#     'width': 960,
#     'height': 1706,
#     'croppingWindow': {'anchorX': 0,
#      'anchorY': 0,
#      'width': 960,
#      'height': 1280}},
#    {'id': '092ee8a2-8c5c-474e-96d3-c1aca9898d06',
#     'url': 'https://i.imgur.com/AWHlOiY.jpg',
#     'normalizedUrl': 'https://imgur.com/AWHlOiY',
#     'thumbnail': 'https://i.imgur.com/AWHlOiYl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T21:02:05.857Z',
#     'updatedAt': '2020-12-24T21:07:28.019Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '302ce573-e9f6-4555-8515-b64fe290bd6a',
#     'url': 'https://i.imgur.com/TPH4SUb.jpg',
#     'normalizedUrl': 'https://imgur.com/TPH4SUb',
#     'thumbnail': 'https://i.imgur.com/TPH4SUbl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T21:02:05.857Z',
#     'updatedAt': '2020-12-24T21:07:28.019Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '8341dbfb-2ab4-4d1a-999a-4a6874e99e6f',
#     'url': 'https://i.imgur.com/SOD3yIe.jpg',
#     'normalizedUrl': 'https://imgur.com/SOD3yIe',
#     'thumbnail': 'https://i.imgur.com/SOD3yIel.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T21:02:05.857Z',
#     'updatedAt': '2020-12-24T21:07:28.019Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': 'd3fc4ca3-fda9-4521-becb-9eb1dc0f4832',
#     'url': 'https://i.imgur.com/Mez7C6w.jpg',
#     'normalizedUrl': 'https://imgur.com/Mez7C6w',
#     'thumbnail': 'https://i.imgur.com/Mez7C6wl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T21:02:05.857Z',
#     'updatedAt': '2020-12-24T21:07:28.019Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '1af8c8bd-6ff6-4993-ae22-3d0e7264897c',
#     'url': 'https://i.imgur.com/8WL5G92.jpg',
#     'normalizedUrl': 'https://imgur.com/8WL5G92',
#     'thumbnail': 'https://i.imgur.com/8WL5G92l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T21:02:05.857Z',
#     'updatedAt': '2020-12-24T21:07:28.019Z',
#     'width': 2000,
#     'height': 1500},
#    {'id': '8563f7ea-b9ab-4e65-a122-8f429d700319',
#     'url': 'https://i.imgur.com/eNlVVcB.jpg',
#     'normalizedUrl': 'https://imgur.com/eNlVVcB',
#     'thumbnail': 'https://i.imgur.com/eNlVVcBl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T21:02:05.857Z',
#     'updatedAt': '2020-12-24T21:07:28.019Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': 'b4e5debe-cedd-4e96-a86b-404fd48c8ee7',
#     'url': 'https://i.imgur.com/KmRcfFx.jpg',
#     'normalizedUrl': 'https://imgur.com/KmRcfFx',
#     'thumbnail': 'https://i.imgur.com/KmRcfFxl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T21:02:05.857Z',
#     'updatedAt': '2020-12-24T21:07:28.019Z',
#     'width': 2000,
#     'height': 1500},
#    {'id': 'a3a9cf74-8700-4e90-9ec4-324c881f4484',
#     'url': 'https://i.imgur.com/UUjL29o.jpg',
#     'normalizedUrl': 'https://imgur.com/UUjL29o',
#     'thumbnail': 'https://i.imgur.com/UUjL29ol.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T21:02:05.857Z',
#     'updatedAt': '2020-12-24T21:07:28.019Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '18c5ce68-f259-46ec-853c-c72177c895e4',
#     'url': 'https://i.imgur.com/aJay0hs.jpg',
#     'normalizedUrl': 'https://imgur.com/aJay0hs',
#     'thumbnail': 'https://i.imgur.com/aJay0hsl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T21:02:05.857Z',
#     'updatedAt': '2020-12-24T21:07:28.019Z',
#     'width': 2000,
#     'height': 1500},
#    {'id': '28813f47-6e55-4135-9152-9ee2bc397fff',
#     'url': 'https://i.imgur.com/ITxYO3V.jpg',
#     'normalizedUrl': 'https://imgur.com/ITxYO3V',
#     'thumbnail': 'https://i.imgur.com/ITxYO3Vl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T21:02:05.857Z',
#     'updatedAt': '2020-12-24T21:07:28.019Z',
#     'width': 1500,
#     'height': 2000}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 148}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/rMF6wO7.jpg'},
#    {'url': 'https://i.imgur.com/AWHlOiY.jpg'},
#    {'url': 'https://i.imgur.com/TPH4SUb.jpg'},
#    {'url': 'https://i.imgur.com/SOD3yIe.jpg'},
#    {'url': 'https://i.imgur.com/Mez7C6w.jpg'},
#    {'url': 'https://i.imgur.com/8WL5G92.jpg'},
#    {'url': 'https://i.imgur.com/eNlVVcB.jpg'},
#    {'url': 'https://i.imgur.com/KmRcfFx.jpg'},
#    {'url': 'https://i.imgur.com/UUjL29o.jpg'},
#    {'url': 'https://i.imgur.com/aJay0hs.jpg'},
#    {'url': 'https://i.imgur.com/ITxYO3V.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 235043261,
#   'title': '關於我家的公貓們',
#   'excerpt': '養了公貓才發現他們真的超愛撒嬌，彼此的感情也超好，本來是想納為大姐頭的後宮的，但後宮們自己卻玩得很開心（？這表情也太母湯ಥ_ಥ，好喔...抱歉打擾了，.，.，.，因為這樣所以大姐頭不高興了，只好出手教',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-12-24T11:30:58.546Z',
#   'updatedAt': '2020-12-24T11:30:58.546Z',
#   'commentCount': 11,
#   'likeCount': 132,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['寵物', '貓', '哈娜', '咪嚕', 'Yuki'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '中華科技大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '3bf2f035-f064-4b00-9d1b-81b73563498f',
#     'url': 'https://i.imgur.com/PS2wVmpl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/PS2wVmpl.jpg',
#     'thumbnail': 'https://i.imgur.com/PS2wVmpl.jpg',
#     'type': 'image/thumbnail',
#     'tags': [],
#     'createdAt': '2020-12-24T11:30:58.546Z',
#     'updatedAt': '2020-12-24T11:30:58.546Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '3bf2f035-f064-4b00-9d1b-81b73563498f',
#     'url': 'https://i.imgur.com/PS2wVmp.jpg',
#     'normalizedUrl': 'https://imgur.com/PS2wVmp',
#     'thumbnail': 'https://i.imgur.com/PS2wVmpl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-24T11:30:58.546Z',
#     'updatedAt': '2020-12-24T11:30:58.546Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '1233e076-da48-4416-86d6-54b75a9948c2',
#     'url': 'https://i.imgur.com/a8fEG8t.jpg',
#     'normalizedUrl': 'https://imgur.com/a8fEG8t',
#     'thumbnail': 'https://i.imgur.com/a8fEG8tl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-24T11:30:58.546Z',
#     'updatedAt': '2020-12-24T11:30:58.546Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '69e05c15-3c46-417d-92cb-7c205cf106b4',
#     'url': 'https://i.imgur.com/1GUEEvm.jpg',
#     'normalizedUrl': 'https://imgur.com/1GUEEvm',
#     'thumbnail': 'https://i.imgur.com/1GUEEvml.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-24T11:30:58.546Z',
#     'updatedAt': '2020-12-24T11:30:58.546Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '36b3d0e3-c80a-423f-9cd9-61582bcd5d2c',
#     'url': 'https://i.imgur.com/LUvAFg9.jpg',
#     'normalizedUrl': 'https://imgur.com/LUvAFg9',
#     'thumbnail': 'https://i.imgur.com/LUvAFg9l.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-24T11:30:58.546Z',
#     'updatedAt': '2020-12-24T11:30:58.546Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': 'ebb21c15-ed7d-4394-b60a-bfe604d98197',
#     'url': 'https://i.imgur.com/7p4g8HO.jpg',
#     'normalizedUrl': 'https://imgur.com/7p4g8HO',
#     'thumbnail': 'https://i.imgur.com/7p4g8HOl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-24T11:30:58.546Z',
#     'updatedAt': '2020-12-24T11:30:58.546Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '57759fef-0bfb-4206-bbaf-efc5e3605711',
#     'url': 'https://i.imgur.com/OhD7M4j.jpg',
#     'normalizedUrl': 'https://imgur.com/OhD7M4j',
#     'thumbnail': 'https://i.imgur.com/OhD7M4jl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-24T11:30:58.546Z',
#     'updatedAt': '2020-12-24T11:30:58.546Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '6384f043-40c2-43d4-9785-b4134bd1c36c',
#     'url': 'https://i.imgur.com/l7lqjTY.jpg',
#     'normalizedUrl': 'https://imgur.com/l7lqjTY',
#     'thumbnail': 'https://i.imgur.com/l7lqjTYl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-24T11:30:58.546Z',
#     'updatedAt': '2020-12-24T11:30:58.546Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '43e600cf-f6b8-4c0b-be40-5c0ee5f36697',
#     'url': 'https://i.imgur.com/ak0dkzR.jpg',
#     'normalizedUrl': 'https://imgur.com/ak0dkzR',
#     'thumbnail': 'https://i.imgur.com/ak0dkzRl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-24T11:30:58.546Z',
#     'updatedAt': '2020-12-24T11:30:58.546Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '61485d7b-c5cc-45de-912b-4c253d3d33d9',
#     'url': 'https://i.imgur.com/ZQC5unK.jpg',
#     'normalizedUrl': 'https://imgur.com/ZQC5unK',
#     'thumbnail': 'https://i.imgur.com/ZQC5unKl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-24T11:30:58.546Z',
#     'updatedAt': '2020-12-24T11:30:58.546Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '9e95f46c-fa0a-4b21-bb29-bf4851bcab21',
#     'url': 'https://i.imgur.com/EnIPiF2.jpg',
#     'normalizedUrl': 'https://imgur.com/EnIPiF2',
#     'thumbnail': 'https://i.imgur.com/EnIPiF2l.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-24T11:30:58.546Z',
#     'updatedAt': '2020-12-24T11:30:58.546Z',
#     'width': 1500,
#     'height': 2000}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 128},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 3},
#    {'id': 'aa0d425f-d530-4478-9a77-fe3aedc79eea', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/PS2wVmp.jpg'},
#    {'url': 'https://i.imgur.com/a8fEG8t.jpg'},
#    {'url': 'https://i.imgur.com/1GUEEvm.jpg'},
#    {'url': 'https://i.imgur.com/LUvAFg9.jpg'},
#    {'url': 'https://i.imgur.com/7p4g8HO.jpg'},
#    {'url': 'https://i.imgur.com/OhD7M4j.jpg'},
#    {'url': 'https://i.imgur.com/l7lqjTY.jpg'},
#    {'url': 'https://i.imgur.com/ak0dkzR.jpg'},
#    {'url': 'https://i.imgur.com/ZQC5unK.jpg'},
#    {'url': 'https://i.imgur.com/EnIPiF2.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 235045203,
#   'title': '直接原地融化！🐈🤪',
#   'excerpt': '每次看都覺得這顏色也太美了吧！，我也太幸運了吧，養到這隻貓貓🥳，忘了說！他叫尼哥唷 叫他還搖尾巴 可愛死了，—————————————————————，更新一下 今天吃葉子的尼哥！（沒真的吃，那無處安',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-12-24T16:19:37.020Z',
#   'updatedAt': '2020-12-25T09:52:38.808Z',
#   'commentCount': 19,
#   'likeCount': 130,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['寵物', '貓', '可愛'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'M',
#   'school': 'BB',
#   'department': 'zhou_325',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '9f5d2949-201b-47ab-865a-c250c78020bd',
#     'url': 'https://vivid.dcard.tw/Public/89afc140-9ac8-4aa2-be8e-d9f237e882ed/thumbnail.jpg',
#     'normalizedUrl': 'https://vivid.dcard.tw/Public/89afc140-9ac8-4aa2-be8e-d9f237e882ed/thumbnail.jpg',
#     'thumbnail': 'https://vivid.dcard.tw/Public/89afc140-9ac8-4aa2-be8e-d9f237e882ed/thumbnail.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2020-12-24T16:19:37.020Z',
#     'updatedAt': '2020-12-25T09:52:38.808Z'},
#    {'id': '9f5d2949-201b-47ab-865a-c250c78020bd',
#     'url': 'https://www.dcard.tw/v2/vivid/videos/89afc140-9ac8-4aa2-be8e-d9f237e882ed?r=1.3333333333333333',
#     'normalizedUrl': '',
#     'thumbnail': 'https://vivid.dcard.tw/Public/89afc140-9ac8-4aa2-be8e-d9f237e882ed/thumbnail.jpg',
#     'type': 'video/vivid',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2020-12-24T16:19:37.020Z',
#     'updatedAt': '2020-12-25T09:52:38.808Z'},
#    {'id': '635646a6-3eaf-4387-95b1-9bc8f70e7acc',
#     'url': 'https://www.dcard.tw/v2/vivid/videos/af9e1977-3253-4ef6-b20a-07b480e1ae52?r=1.7777777777777777',
#     'normalizedUrl': '',
#     'thumbnail': 'https://vivid.dcard.tw/Public/af9e1977-3253-4ef6-b20a-07b480e1ae52/thumbnail.jpg',
#     'type': 'video/vivid',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2020-12-24T16:19:37.020Z',
#     'updatedAt': '2020-12-25T09:52:38.808Z'},
#    {'id': '20a3c451-0a21-4c2a-8470-2381e536c377',
#     'url': 'https://i.imgur.com/tXZghoI.jpg',
#     'normalizedUrl': 'https://imgur.com/tXZghoI',
#     'thumbnail': 'https://i.imgur.com/tXZghoIl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-25T09:52:38.808Z',
#     'updatedAt': '2020-12-25T09:52:38.808Z',
#     'width': 1500,
#     'height': 2000}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 128},
#    {'id': 'aa0d425f-d530-4478-9a77-fe3aedc79eea', 'count': 1},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'withImages': True,
#   'withVideos': True,
#   'media': [{'url': 'https://vivid.dcard.tw/Public/89afc140-9ac8-4aa2-be8e-d9f237e882ed/thumbnail.jpg'},
#    {'url': 'https://vivid.dcard.tw/Public/af9e1977-3253-4ef6-b20a-07b480e1ae52/thumbnail.jpg'},
#    {'url': 'https://i.imgur.com/tXZghoI.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 235047436,
#   'title': '每天回家的喵喵叫迎接（開聲音）',
#   'excerpt': '看文章之前，請先拿起耳機 開聲音，這篇文章的靈魂是喵喵叫！！！，首圖封片跟大家先說 聖誕快樂，今天來發一個關於我回家就會用瘋狂喵喵叫迎接我的影片，我家貓其實平常都不會叫，不管怎麼玩她都不會，但我下班回',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-12-25T04:32:56.936Z',
#   'updatedAt': '2020-12-25T04:36:20.563Z',
#   'commentCount': 13,
#   'likeCount': 78,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['布偶貓', '小翠花小姐', '喵喵叫'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'M',
#   'school': '翠花爸',
#   'department': 'doge_g.m',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '4f8ffe91-35d1-4af3-b78c-6dc3ff957983',
#     'url': 'https://i.imgur.com/dOKrSKvl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/dOKrSKvl.jpg',
#     'thumbnail': 'https://i.imgur.com/dOKrSKvl.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-25T04:32:56.936Z',
#     'updatedAt': '2020-12-25T04:36:20.563Z',
#     'width': 1125,
#     'height': 1125},
#    {'id': '4f8ffe91-35d1-4af3-b78c-6dc3ff957983',
#     'url': 'https://i.imgur.com/dOKrSKv.jpg',
#     'normalizedUrl': 'https://imgur.com/dOKrSKv',
#     'thumbnail': 'https://i.imgur.com/dOKrSKvl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-25T04:32:56.936Z',
#     'updatedAt': '2020-12-25T04:36:20.563Z',
#     'width': 1125,
#     'height': 1125},
#    {'id': '41aa4824-f265-409a-a235-cf56b5d161b6',
#     'url': 'https://www.dcard.tw/v2/vivid/videos/9190e649-7f34-4d3d-9889-24032fcf327f?r=1.7777777777777777',
#     'normalizedUrl': '',
#     'thumbnail': 'https://vivid.dcard.tw/Public/9190e649-7f34-4d3d-9889-24032fcf327f/thumbnail.jpg',
#     'type': 'video/vivid',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2020-12-25T04:32:56.936Z',
#     'updatedAt': '2020-12-25T04:36:20.563Z'},
#    {'id': 'e75994bc-3d6d-448b-a12a-3406b9ef8db9',
#     'url': 'https://www.dcard.tw/v2/vivid/videos/c864d464-5d21-4c49-8f22-11ee137044a4?r=1.7777777777777777',
#     'normalizedUrl': '',
#     'thumbnail': 'https://vivid.dcard.tw/Public/c864d464-5d21-4c49-8f22-11ee137044a4/thumbnail.jpg',
#     'type': 'video/vivid',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2020-12-25T04:32:56.936Z',
#     'updatedAt': '2020-12-25T04:36:20.563Z'},
#    {'id': 'b3e4b7bf-b839-4821-b3c5-62a5b08865d2',
#     'url': 'https://www.dcard.tw/v2/vivid/videos/3a948a3d-0d23-46cf-800e-46697e09e0a7?r=1.7777777777777777',
#     'normalizedUrl': '',
#     'thumbnail': 'https://vivid.dcard.tw/Public/3a948a3d-0d23-46cf-800e-46697e09e0a7/thumbnail.jpg',
#     'type': 'video/vivid',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2020-12-25T04:36:20.563Z',
#     'updatedAt': '2020-12-25T04:36:20.563Z'},
#    {'id': 'b0b3a449-445c-4470-b460-93a08f5e3d13',
#     'url': 'https://i.imgur.com/18tytyY.jpg',
#     'normalizedUrl': 'https://imgur.com/18tytyY',
#     'thumbnail': 'https://i.imgur.com/18tytyYl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-25T04:32:56.936Z',
#     'updatedAt': '2020-12-25T04:36:20.563Z',
#     'width': 988,
#     'height': 988}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 78}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'withImages': True,
#   'withVideos': True,
#   'media': [{'url': 'https://i.imgur.com/dOKrSKv.jpg'},
#    {'url': 'https://vivid.dcard.tw/Public/9190e649-7f34-4d3d-9889-24032fcf327f/thumbnail.jpg'},
#    {'url': 'https://vivid.dcard.tw/Public/c864d464-5d21-4c49-8f22-11ee137044a4/thumbnail.jpg'},
#    {'url': 'https://vivid.dcard.tw/Public/3a948a3d-0d23-46cf-800e-46697e09e0a7/thumbnail.jpg'},
#    {'url': 'https://i.imgur.com/18tytyY.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 235045427,
#   'title': '遛貓超不專業分享',
#   'excerpt': '最近看到某文章在討論貓咪很小就帶出去遛有點激烈，我家的貓也很小就被我帶出去亂晃了，所以拜託大家不喜勿入我沒有虐貓🥺，但我絕對是不支持帶貓出門還有打賞的那種：），正文，各位好自從我9月養了一隻屁貓之後，',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-12-24T16:47:56.751Z',
#   'updatedAt': '2020-12-25T03:35:12.373Z',
#   'commentCount': 4,
#   'likeCount': 69,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['遛貓', '貓', '寵物', '貓咪', '幼貓'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '歐哩是一隻屁貓',
#   'department': 'h.9527',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '3e8388bb-6fce-47e5-b93c-e487d3e47f9b',
#     'url': 'https://i.imgur.com/TCJNHhTl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/TCJNHhTl.jpg',
#     'thumbnail': 'https://i.imgur.com/TCJNHhTl.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-25T03:34:34.827Z',
#     'updatedAt': '2020-12-25T03:35:12.373Z',
#     'width': 1620,
#     'height': 1080},
#    {'id': '3e8388bb-6fce-47e5-b93c-e487d3e47f9b',
#     'url': 'https://i.imgur.com/TCJNHhT.jpg',
#     'normalizedUrl': 'https://imgur.com/TCJNHhT',
#     'thumbnail': 'https://i.imgur.com/TCJNHhTl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-25T03:34:34.827Z',
#     'updatedAt': '2020-12-25T03:35:12.373Z',
#     'width': 1620,
#     'height': 1080},
#    {'id': '7c4f98e5-78d9-4896-a358-19b080a57e9e',
#     'url': 'https://www.dcard.tw/v2/vivid/videos/d8caf342-cb62-49b8-885e-dc97ef7df63f?r=1.7777777777777777',
#     'normalizedUrl': '',
#     'thumbnail': 'https://vivid.dcard.tw/Public/d8caf342-cb62-49b8-885e-dc97ef7df63f/thumbnail.jpg',
#     'type': 'video/vivid',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2020-12-24T16:47:56.751Z',
#     'updatedAt': '2020-12-25T03:35:12.373Z'},
#    {'id': '082ba682-cdd1-48e8-9285-9e77cbe887f8',
#     'url': 'https://i.imgur.com/PqEnHL0.jpg',
#     'normalizedUrl': 'https://imgur.com/PqEnHL0',
#     'thumbnail': 'https://i.imgur.com/PqEnHL0l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T16:47:56.751Z',
#     'updatedAt': '2020-12-25T03:35:12.373Z',
#     'width': 1620,
#     'height': 1080},
#    {'id': '8b277d25-7148-4e7b-b993-d83a5ec112dd',
#     'url': 'https://i.imgur.com/IzWkQFG.jpg',
#     'normalizedUrl': 'https://imgur.com/IzWkQFG',
#     'thumbnail': 'https://i.imgur.com/IzWkQFGl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T16:47:56.751Z',
#     'updatedAt': '2020-12-25T03:35:12.373Z',
#     'width': 2000,
#     'height': 1500},
#    {'id': '7fe9f42d-0ee0-4388-98cd-db84aa2ac1d3',
#     'url': 'https://i.imgur.com/Ig6GYKs.jpg',
#     'normalizedUrl': 'https://imgur.com/Ig6GYKs',
#     'thumbnail': 'https://i.imgur.com/Ig6GYKsl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T16:47:56.751Z',
#     'updatedAt': '2020-12-25T03:35:12.373Z',
#     'width': 1620,
#     'height': 1080},
#    {'id': '1eb0ff30-bd75-4ebd-89ed-5dad1b3c4eb4',
#     'url': 'https://i.imgur.com/isNQ554.jpg',
#     'normalizedUrl': 'https://imgur.com/isNQ554',
#     'thumbnail': 'https://i.imgur.com/isNQ554l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T16:47:56.751Z',
#     'updatedAt': '2020-12-25T03:35:12.373Z',
#     'width': 1620,
#     'height': 1080},
#    {'id': 'f207e938-1c78-4221-85d2-6eedbce29cd7',
#     'url': 'https://i.imgur.com/ZLQiq0g.jpg',
#     'normalizedUrl': 'https://imgur.com/ZLQiq0g',
#     'thumbnail': 'https://i.imgur.com/ZLQiq0gl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T16:47:56.751Z',
#     'updatedAt': '2020-12-25T03:35:12.373Z',
#     'width': 1620,
#     'height': 1080},
#    {'id': 'aa86c066-5cef-4670-826d-a850651add79',
#     'url': 'https://i.imgur.com/3hH23vx.jpg',
#     'normalizedUrl': 'https://imgur.com/3hH23vx',
#     'thumbnail': 'https://i.imgur.com/3hH23vxl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T16:47:56.751Z',
#     'updatedAt': '2020-12-25T03:35:12.373Z',
#     'width': 1080,
#     'height': 1620},
#    {'id': 'e09c1eda-0c7c-413b-ad68-a28c317b3c62',
#     'url': 'https://i.imgur.com/92kY0Ru.jpg',
#     'normalizedUrl': 'https://imgur.com/92kY0Ru',
#     'thumbnail': 'https://i.imgur.com/92kY0Rul.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T16:47:56.751Z',
#     'updatedAt': '2020-12-25T03:35:12.373Z',
#     'width': 1080,
#     'height': 1620},
#    {'id': 'a98d837c-95f2-46c4-8cc0-a30b88198563',
#     'url': 'https://i.imgur.com/FxwyfQx.jpg',
#     'normalizedUrl': 'https://imgur.com/FxwyfQx',
#     'thumbnail': 'https://i.imgur.com/FxwyfQxl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T16:47:56.751Z',
#     'updatedAt': '2020-12-25T03:35:12.373Z',
#     'width': 909,
#     'height': 1366},
#    {'id': 'a54b6456-2956-4966-a35d-72302dc2bf85',
#     'url': 'https://i.imgur.com/GyGAeDw.jpg',
#     'normalizedUrl': 'https://imgur.com/GyGAeDw',
#     'thumbnail': 'https://i.imgur.com/GyGAeDwl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T16:47:56.751Z',
#     'updatedAt': '2020-12-25T03:35:12.373Z',
#     'width': 1080,
#     'height': 1620},
#    {'id': 'ab551b69-6f63-4c6d-b6d2-59705f51371b',
#     'url': 'https://i.imgur.com/zP4E9VG.jpg',
#     'normalizedUrl': 'https://imgur.com/zP4E9VG',
#     'thumbnail': 'https://i.imgur.com/zP4E9VGl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T16:47:56.751Z',
#     'updatedAt': '2020-12-25T03:35:12.373Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '13820e5a-cc24-4c61-a672-cc380dce4f11',
#     'url': 'https://i.imgur.com/Ss5seb9.jpg',
#     'normalizedUrl': 'https://imgur.com/Ss5seb9',
#     'thumbnail': 'https://i.imgur.com/Ss5seb9l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T16:47:56.751Z',
#     'updatedAt': '2020-12-25T03:35:12.373Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': '2a52db97-7e3b-4881-b2cd-88ca87b6b204',
#     'url': 'https://i.imgur.com/JVszG0Z.jpg',
#     'normalizedUrl': 'https://imgur.com/JVszG0Z',
#     'thumbnail': 'https://i.imgur.com/JVszG0Zl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T16:47:56.751Z',
#     'updatedAt': '2020-12-25T03:35:12.373Z',
#     'width': 427,
#     'height': 463}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 69}],
# ...
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/fr6aEUA.jpg'},
#    {'url': 'https://i.imgur.com/Tq6S9LF.jpg'},
#    {'url': 'https://i.imgur.com/cZ140qE.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 235048707,
#   'title': '默默跑完一圈公園',
#   'excerpt': '趁著今天還見得到陽光時，順便帶狗狗透透氣，以解這幾天無法外出之憂愁。由於剛打完針和加上須吃「防體內外蟲子」的藥物，近期才帶dobby外出蹓躂。爆笑的事情，也一籮筐的出現...，天氣冷，先穿上近兩年的當',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-12-25T08:41:58.898Z',
#   'updatedAt': '2020-12-25T08:43:22.211Z',
#   'commentCount': 2,
#   'likeCount': 14,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['寵物', '狗', '巴哥', '慢跑', '公園'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'M',
#   'school': '小蚵仔Dobby',
#   'department': 'pugdobby_tw',
#   'replyTitle': None,
#   'mediaMeta': [{'id': 'd49091eb-956f-4ee4-95d7-6f1f420aa778',
#     'url': 'https://i.imgur.com/M4S1uLTl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/M4S1uLTl.jpg',
#     'thumbnail': 'https://i.imgur.com/M4S1uLTl.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-25T08:41:58.898Z',
#     'updatedAt': '2020-12-25T08:43:22.211Z',
#     'width': 1500,
#     'height': 2000,
#     'croppingWindow': {'anchorX': 0,
#      'anchorY': 0,
#      'width': 1500,
#      'height': 2000}},
#    {'id': 'd49091eb-956f-4ee4-95d7-6f1f420aa778',
#     'url': 'https://i.imgur.com/M4S1uLT.jpg',
#     'normalizedUrl': 'https://imgur.com/M4S1uLT',
#     'thumbnail': 'https://i.imgur.com/M4S1uLTl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-25T08:41:58.898Z',
#     'updatedAt': '2020-12-25T08:43:22.211Z',
#     'width': 1500,
#     'height': 2000,
#     'croppingWindow': {'anchorX': 0,
#      'anchorY': 0,
#      'width': 1500,
#      'height': 2000}},
#    {'id': '1aa3eb47-e7eb-4144-9d57-1a1d1a40bde0',
#     'url': 'https://i.imgur.com/Hvy43vT.jpg',
#     'normalizedUrl': 'https://imgur.com/Hvy43vT',
#     'thumbnail': 'https://i.imgur.com/Hvy43vTl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-25T08:41:58.898Z',
#     'updatedAt': '2020-12-25T08:43:22.211Z',
#     'width': 2000,
#     'height': 1499},
#    {'id': '4cf63e3e-a254-4356-8981-7dda86bc1dc4',
#     'url': 'https://i.imgur.com/7J2FMJD.jpg',
#     'normalizedUrl': 'https://imgur.com/7J2FMJD',
#     'thumbnail': 'https://i.imgur.com/7J2FMJDl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-25T08:41:58.898Z',
#     'updatedAt': '2020-12-25T08:43:22.211Z',
#     'width': 2000,
#     'height': 1536},
#    {'id': '7efd3bc5-426a-4d29-9cf4-202b97a40fe9',
#     'url': 'https://i.imgur.com/Lot3o5b.jpg',
#     'normalizedUrl': 'https://imgur.com/Lot3o5b',
#     'thumbnail': 'https://i.imgur.com/Lot3o5bl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-25T08:41:58.898Z',
#     'updatedAt': '2020-12-25T08:43:22.211Z',
#     'width': 2000,
#     'height': 1500},
#    {'id': '12edbe4f-e46d-4e07-96b3-c8d1627064bc',
#     'url': 'https://i.imgur.com/HsOhOMB.jpg',
#     'normalizedUrl': 'https://imgur.com/HsOhOMB',
#     'thumbnail': 'https://i.imgur.com/HsOhOMBl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-25T08:41:58.898Z',
#     'updatedAt': '2020-12-25T08:43:22.211Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '10e20276-5121-4270-910d-b4a08dba06c9',
#     'url': 'https://i.imgur.com/fMGFk24.jpg',
#     'normalizedUrl': 'https://imgur.com/fMGFk24',
#     'thumbnail': 'https://i.imgur.com/fMGFk24l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-25T08:41:58.898Z',
#     'updatedAt': '2020-12-25T08:43:22.211Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '3ee678ff-d93a-4be9-a038-817eebf45071',
#     'url': 'https://i.imgur.com/5u5WJ9l.jpg',
#     'normalizedUrl': 'https://imgur.com/5u5WJ9l',
#     'thumbnail': 'https://i.imgur.com/5u5WJ9ll.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-25T08:41:58.898Z',
#     'updatedAt': '2020-12-25T08:43:22.211Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '70f07231-018e-48a3-af29-f7fc98381321',
#     'url': 'https://i.imgur.com/ABmlks2.jpg',
#     'normalizedUrl': 'https://imgur.com/ABmlks2',
#     'thumbnail': 'https://i.imgur.com/ABmlks2l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-25T08:41:58.898Z',
#     'updatedAt': '2020-12-25T08:43:22.211Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': 'a3b6712d-9376-4e6d-9c94-bed031513a23',
#     'url': 'https://www.dcard.tw/v2/vivid/videos/436c8ba9-b5b2-419d-baa6-11a61a0bd74c?r=1.7777777777777777',
#     'normalizedUrl': '',
#     'thumbnail': 'https://vivid.dcard.tw/Public/436c8ba9-b5b2-419d-baa6-11a61a0bd74c/thumbnail.jpg',
#     'type': 'video/vivid',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2020-12-25T08:41:58.898Z',
#     'updatedAt': '2020-12-25T08:43:22.211Z'},
#    {'id': '5ee49e8f-5400-4ee7-895c-fa9d3e549bc5',
#     'url': 'https://i.imgur.com/v1O27lQ.jpg',
#     'normalizedUrl': 'https://imgur.com/v1O27lQ',
#     'thumbnail': 'https://i.imgur.com/v1O27lQl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-25T08:41:58.898Z',
#     'updatedAt': '2020-12-25T08:43:22.211Z',
#     'width': 1500,
#     'height': 2000}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 13},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'withImages': True,
#   'withVideos': True,
#   'media': [{'url': 'https://i.imgur.com/M4S1uLT.jpg'},
#    {'url': 'https://i.imgur.com/Hvy43vT.jpg'},
#    {'url': 'https://i.imgur.com/7J2FMJD.jpg'},
#    {'url': 'https://i.imgur.com/Lot3o5b.jpg'},
#    {'url': 'https://i.imgur.com/HsOhOMB.jpg'},
#    {'url': 'https://i.imgur.com/fMGFk24.jpg'},
#    {'url': 'https://i.imgur.com/5u5WJ9l.jpg'},
#    {'url': 'https://i.imgur.com/ABmlks2.jpg'},
#    {'url': 'https://vivid.dcard.tw/Public/436c8ba9-b5b2-419d-baa6-11a61a0bd74c/thumbnail.jpg'},
#    {'url': 'https://i.imgur.com/v1O27lQ.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 235047324,
#   'title': '聖誕快樂🐱',
#   'excerpt': '又到了聖誕節的時候了，祝大家聖誕快樂，防疫期間勤洗手攜帶口罩，保持社交距離，曬一下我家的🥰',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-12-25T04:08:53.299Z',
#   'updatedAt': '2020-12-25T04:08:53.299Z',
#   'commentCount': 2,
#   'likeCount': 14,
#   'withNickname': True,
#   'tags': ['HIDE_THUMBNAIL'],
#   'topics': ['寵物', '貓'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'M',
#   'school': 'Mr.R',
#   'department': 'peter0412',
#   'replyTitle': None,
#   'mediaMeta': [{'id': 'b4230b45-d314-4e8b-8ec9-c9dd829f3d42',
#     'url': 'https://i.imgur.com/DSt7Mo8.jpg',
#     'normalizedUrl': 'https://imgur.com/DSt7Mo8',
#     'thumbnail': 'https://i.imgur.com/DSt7Mo8l.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-25T04:08:53.299Z',
#     'updatedAt': '2020-12-25T04:08:53.299Z',
#     'width': 1108,
#     'height': 1478},
#    {'id': '69c7b808-5c01-422e-aedb-852afbe58a40',
#     'url': 'https://i.imgur.com/RvO2WKO.jpg',
#     'normalizedUrl': 'https://imgur.com/RvO2WKO',
#     'thumbnail': 'https://i.imgur.com/RvO2WKOl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-25T04:08:53.299Z',
#     'updatedAt': '2020-12-25T04:08:53.299Z',
#     'width': 1478,
#     'height': 1108},
#    {'id': 'abb06128-d58f-4557-9abe-57f0a92f013c',
#     'url': 'https://i.imgur.com/8CMbykO.jpg',
#     'normalizedUrl': 'https://imgur.com/8CMbykO',
#     'thumbnail': 'https://i.imgur.com/8CMbykOl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-25T04:08:53.299Z',
#     'updatedAt': '2020-12-25T04:08:53.299Z',
#     'width': 1108,
#     'height': 1478},
#    {'id': '8f24e335-b5ae-4a5a-b231-b5187c09b83b',
#     'url': 'https://i.imgur.com/WpD6bY1.jpg',
#     'normalizedUrl': 'https://imgur.com/WpD6bY1',
#     'thumbnail': 'https://i.imgur.com/WpD6bY1l.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-25T04:08:53.299Z',
#     'updatedAt': '2020-12-25T04:08:53.299Z',
#     'width': 1108,
#     'height': 1478},
#    {'id': '558e9022-791d-452f-b007-925786bd23c3',
#     'url': 'https://www.dcard.tw/v2/vivid/videos/fc857262-fca3-4987-9042-e91809f7c07b?r=1.3333333333333333',
#     'normalizedUrl': '',
#     'thumbnail': 'https://vivid.dcard.tw/Public/fc857262-fca3-4987-9042-e91809f7c07b/thumbnail.jpg',
#     'type': 'video/vivid',
#     'tags': [],
#     'createdAt': '2020-12-25T04:08:53.299Z',
#     'updatedAt': '2020-12-25T04:08:53.299Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 14}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'withImages': True,
#   'withVideos': True,
#   'media': [],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 235043817,
#   'title': '冬天就是要睡覺阿 不然要幹嘛？',
#   'excerpt': '冬天來了～路上好多貓貓也跟著貪睡，石頭就是我的枕頭，只是這樣子脖子不會扭到嗎？？室友關係？？一個上下鋪的概念🤔🤔，我只是瞇一下下而已喔🤗，睡到肚肚都被我看光光了🤤，先補個眠 Zz晚上才能嗨，旁邊那個人',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-12-24T13:09:03.193Z',
#   'updatedAt': '2020-12-24T13:12:22.699Z',
#   'commentCount': 0,
#   'likeCount': 14,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['睡覺', '貓貓', '冬天'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '國立臺北大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': 'cfcee144-e715-454b-8c2d-c5073b0746a8',
#     'url': 'https://i.imgur.com/hdC3SxPl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/hdC3SxPl.jpg',
#     'thumbnail': 'https://i.imgur.com/hdC3SxPl.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T13:09:03.193Z',
#     'updatedAt': '2020-12-24T13:12:22.699Z',
#     'width': 1325,
#     'height': 2000,
#     'croppingWindow': {'anchorX': 0,
#      'anchorY': 265,
#      'width': 1325,
#      'height': 795}},
#    {'id': 'cfcee144-e715-454b-8c2d-c5073b0746a8',
#     'url': 'https://i.imgur.com/hdC3SxP.jpg',
#     'normalizedUrl': 'https://imgur.com/hdC3SxP',
#     'thumbnail': 'https://i.imgur.com/hdC3SxPl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T13:09:03.193Z',
#     'updatedAt': '2020-12-24T13:12:22.699Z',
#     'width': 1325,
#     'height': 2000,
#     'croppingWindow': {'anchorX': 0,
#      'anchorY': 265,
#      'width': 1325,
#      'height': 795}},
#    {'id': '9b54a4f0-c2ab-4575-b9d3-f45a81dd72b4',
#     'url': 'https://i.imgur.com/3IiIylk.jpg',
#     'normalizedUrl': 'https://imgur.com/3IiIylk',
#     'thumbnail': 'https://i.imgur.com/3IiIylkl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T13:09:03.193Z',
#     'updatedAt': '2020-12-24T13:12:22.699Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '924ed1e4-df92-4d25-90fb-3c50f11acd6f',
#     'url': 'https://i.imgur.com/x5CznIK.jpg',
#     'normalizedUrl': 'https://imgur.com/x5CznIK',
#     'thumbnail': 'https://i.imgur.com/x5CznIKl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T13:09:03.193Z',
#     'updatedAt': '2020-12-24T13:12:22.699Z',
#     'width': 2000,
#     'height': 1500},
#    {'id': '45f0c864-acd1-48c4-8b09-d34024398e61',
#     'url': 'https://i.imgur.com/nTppU6e.jpg',
#     'normalizedUrl': 'https://imgur.com/nTppU6e',
#     'thumbnail': 'https://i.imgur.com/nTppU6el.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T13:09:03.193Z',
#     'updatedAt': '2020-12-24T13:12:22.699Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': 'be3095d4-b68f-41e8-a4b2-7d54160c0ff0',
#     'url': 'https://i.imgur.com/QynxyyQ.jpg',
#     'normalizedUrl': 'https://imgur.com/QynxyyQ',
#     'thumbnail': 'https://i.imgur.com/QynxyyQl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T13:09:03.193Z',
#     'updatedAt': '2020-12-24T13:12:22.699Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '87d49db1-c867-448e-bf32-ce62e0553104',
#     'url': 'https://i.imgur.com/yGiwbL3.jpg',
#     'normalizedUrl': 'https://imgur.com/yGiwbL3',
#     'thumbnail': 'https://i.imgur.com/yGiwbL3l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T13:09:03.193Z',
#     'updatedAt': '2020-12-24T13:12:22.699Z',
#     'width': 2000,
#     'height': 1500}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 14}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/hdC3SxP.jpg'},
#    {'url': 'https://i.imgur.com/3IiIylk.jpg'},
#    {'url': 'https://i.imgur.com/x5CznIK.jpg'},
#    {'url': 'https://i.imgur.com/nTppU6e.jpg'},
#    {'url': 'https://i.imgur.com/QynxyyQ.jpg'},
#    {'url': 'https://i.imgur.com/yGiwbL3.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 235042397,
#   'title': '貓咪走失協尋',
#   'excerpt': '走失地點：台南麻豆（鄰近1+1、福泉豆花一代），名字：柴柴，特徵：母、白底虎斑、有棕色項圈，年齡：6個多月，個性親人、預約結紮前可能被公貓荷爾蒙吸引走了。拜託有看到類似特徵請幫忙留意，並在下方留言回覆',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-12-24T08:46:43.934Z',
#   'updatedAt': '2020-12-24T08:57:05.408Z',
#   'commentCount': 9,
#   'likeCount': 13,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['貓', '走失協尋'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': 'Okokik',
#   'department': 'okokik',
#   'replyTitle': None,
#   'mediaMeta': [{'id': 'ecb6ee25-f71d-4cbb-9e81-b933605c35b7',
#     'url': 'https://i.imgur.com/sDWPD5gl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/sDWPD5gl.jpg',
#     'thumbnail': 'https://i.imgur.com/sDWPD5gl.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T08:46:43.934Z',
#     'updatedAt': '2020-12-24T08:57:05.408Z',
#     'width': 960,
#     'height': 720},
#    {'id': 'ecb6ee25-f71d-4cbb-9e81-b933605c35b7',
#     'url': 'https://i.imgur.com/sDWPD5g.jpg',
#     'normalizedUrl': 'https://imgur.com/sDWPD5g',
#     'thumbnail': 'https://i.imgur.com/sDWPD5gl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T08:46:43.934Z',
#     'updatedAt': '2020-12-24T08:57:05.408Z',
#     'width': 960,
#     'height': 720},
#    {'id': '969d41c3-9ac0-47c8-8e49-6a7c582818de',
#     'url': 'https://i.imgur.com/ZMNMeWV.jpg',
#     'normalizedUrl': 'https://imgur.com/ZMNMeWV',
#     'thumbnail': 'https://i.imgur.com/ZMNMeWVl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-24T08:46:43.934Z',
#     'updatedAt': '2020-12-24T08:57:05.408Z',
#     'width': 720,
#     'height': 960}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 13}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/sDWPD5g.jpg'},
#    {'url': 'https://i.imgur.com/ZMNMeWV.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False}]

# %%
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」

json_form = json.loads(r.text)
ans_arr = []
for v in json_form:
    dic = {}
    dic['title'] = v['title']
    dic['time'] = v['createdAt']
    dic['commentCount'] = v['commentCount']
    dic['likeCount'] = v['likeCount']
    ans_arr.append(dic)
    
# print(ans_arr)
ans_arr
# Out:
# [{'title': '狗媽媽活凍成冰雕，還緊護7隻寶寶',
#   'time': '2020-12-24T09:21:46.019Z',
#   'commentCount': 21,
#   'likeCount': 2916},
#  {'title': '喜歡的寵物店狗狗被買走了',
#   'time': '2020-12-24T14:20:04.070Z',
#   'commentCount': 32,
#   'likeCount': 793},
#  {'title': '求助！貓貓發霉了😫',
#   'time': '2020-12-24T10:22:32.116Z',
#   'commentCount': 34,
#   'likeCount': 273},
#  {'title': '貓咪很秀氣的嘎嘎聲',
#   'time': '2020-12-24T06:19:34.462Z',
#   'commentCount': 15,
#   'likeCount': 218},
#  {'title': '是會不會吃飯啦😂',
#   'time': '2020-12-24T07:07:50.904Z',
#   'commentCount': 8,
#   'likeCount': 205},
#  {'title': '被留在公車上的狗狗(611公車上)',
#   'time': '2020-12-24T01:23:13.256Z',
#   'commentCount': 21,
#   'likeCount': 200},
#  {'title': '是一糰棉花糖！',
#   'time': '2020-12-24T07:52:22.425Z',
#   'commentCount': 10,
#   'likeCount': 167},
#  {'title': '我與膽小貓的故事',
#   'time': '2020-12-24T21:02:05.857Z',
#   'commentCount': 10,
#   'likeCount': 148},
#  {'title': '關於我家的公貓們',
#   'time': '2020-12-24T11:30:58.546Z',
#   'commentCount': 11,
#   'likeCount': 132},
#  {'title': '直接原地融化！🐈🤪',
#   'time': '2020-12-24T16:19:37.020Z',
#   'commentCount': 19,
#   'likeCount': 130},
#  {'title': '每天回家的喵喵叫迎接（開聲音）',
#   'time': '2020-12-25T04:32:56.936Z',
#   'commentCount': 13,
#   'likeCount': 78},
#  {'title': '遛貓超不專業分享',
#   'time': '2020-12-24T16:47:56.751Z',
#   'commentCount': 4,
#   'likeCount': 69},
#  {'title': '鞋貓劍客本貓',
#   'time': '2020-12-24T08:20:03.986Z',
#   'commentCount': 5,
#   'likeCount': 65},
#  {'title': '每看必哭之貓貓圖',
#   'time': '2020-12-24T15:37:56.998Z',
#   'commentCount': 7,
#   'likeCount': 53},
#  {'title': '貓跟聖誕樹🎄共存',
#   'time': '2020-12-24T05:14:08.889Z',
#   'commentCount': 7,
#   'likeCount': 42},
#  {'title': '我是不會給你吃的！',
#   'time': '2020-12-24T14:37:58.549Z',
#   'commentCount': 2,
#   'likeCount': 41},
#  {'title': '幼貓能夠剪指甲嗎',
#   'time': '2020-12-25T01:33:06.358Z',
#   'commentCount': 6,
#   'likeCount': 36},
#  {'title': '拜託不是每隻狗都很友善的',
#   'time': '2020-12-24T13:50:14.253Z',
#   'commentCount': 7,
#   'likeCount': 35},
#  {'title': '貓咪一直亂尿尿怎麼辦🥺',
#   'time': '2020-12-24T13:32:19.733Z',
#   'commentCount': 13,
#   'likeCount': 34},
#  {'title': '我好想牠',
#   'time': '2020-12-24T07:11:48.700Z',
#   'commentCount': 1,
#   'likeCount': 33},
#  {'title': '分享家裡毛孩的反差',
#   'time': '2020-12-25T03:35:39.352Z',
#   'commentCount': 3,
#   'likeCount': 26},
#  {'title': '貓貓一直吸 what’s up?',
#   'time': '2020-12-24T07:55:25.371Z',
#   'commentCount': 2,
#   'likeCount': 22},
#  {'title': '#問 豆娘翅膀黏在一起',
#   'time': '2020-12-25T03:16:06.468Z',
#   'commentCount': 2,
#   'likeCount': 18},
#  {'title': '肥豬豬黑妞',
#   'time': '2020-12-25T05:23:17.371Z',
#   'commentCount': 0,
#   'likeCount': 16},
#  {'title': '一份聖誕Wink請簽收🎄',
#   'time': '2020-12-25T00:44:39.495Z',
#   'commentCount': 0,
#   'likeCount': 16},
#  {'title': '聖誕節最無奈就是你了🤣',
#   'time': '2020-12-24T18:10:49.170Z',
#   'commentCount': 2,
#   'likeCount': 15},
#  {'title': '默默跑完一圈公園',
#   'time': '2020-12-25T08:41:58.898Z',
#   'commentCount': 2,
#   'likeCount': 14},
#  {'title': '聖誕快樂🐱',
#   'time': '2020-12-25T04:08:53.299Z',
#   'commentCount': 2,
#   'likeCount': 14},
#  {'title': '冬天就是要睡覺阿 不然要幹嘛？',
#   'time': '2020-12-24T13:09:03.193Z',
#   'commentCount': 0,
#   'likeCount': 14},
#  {'title': '貓咪走失協尋',
#   'time': '2020-12-24T08:46:43.934Z',
#   'commentCount': 9,
#   'likeCount': 13}]

# %%
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

hot_sum_comment = 0
hot_sum_like = 0
for v in ans_arr:
    hot_sum_comment += v['commentCount']
    hot_sum_like += v['likeCount']
#     print(hot_sum_like, v['likeCount'])

average_commentCount = hot_sum_comment / len(ans_arr)
average_likeCount = hot_sum_like / len(ans_arr)

print('熱門文章的平均留言人數', average_commentCount)
print('熱門文章的平均按讚人數', average_likeCount)
# Out:
# 熱門文章的平均留言人數 8.933333333333334
# 熱門文章的平均按讚人數 194.53333333333333

# %%
ar = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=false')
response2 = ar.text
notHot = json.loads(ar.text)
notHot_ans_arr = []
for v in notHot:
    dic = {}
    dic['commentCount'] = v['commentCount']
    dic['likeCount'] = v['likeCount']
    notHot_ans_arr.append(dic)

notHot_sum_comment = 0
notHot_sum_like = 0
for v in notHot_ans_arr:
    notHot_sum_comment += v['commentCount']
    notHot_sum_like += v['likeCount']
    
notHot_average_commentCount = notHot_sum_comment / len(notHot_ans_arr)
notHot_average_likeCount = notHot_sum_like / len(notHot_ans_arr)

print('非熱門文章的平均留言人數', notHot_average_commentCount)
print('非熱門文章的平均按讚人數', notHot_average_likeCount)
# Out:
# 非熱門文章的平均留言人數 1.9333333333333333
# 非熱門文章的平均按讚人數 10.533333333333333
